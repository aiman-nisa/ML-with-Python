# %% [markdown]
# <a href="https://colab.research.google.com/github/aiman-nisa/ML-with-Python/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# variables
a,b=1,2
print(a,b)
# Out:
# 1 2

# %%
a=1,2,3,4,5
type(a)
a
# Out:
# (1, 2, 3, 4, 5)

# %%
# type cast to list
list (a)
# Out:
# [1, 2, 3, 4, 5]

# %%
def HBT(home_name,Age): #function name(parameter)
    university_name="Rahul"
    if university_name==home_name:
        print ("Happy Birthday to", home_name) #statement
        print("Your age is",Age)
    else:
        print("student does not belongs to university")

# %%
HBT("Mohan",25) #function calling(argument)
# Out:
# student does not belongs to university

# %%
HBT("Rahul",25) #function calling(argument)
# Out:
# Happy Birthday to Rahul
# Your age is 25
